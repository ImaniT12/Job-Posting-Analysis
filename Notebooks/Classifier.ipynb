# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import roc_auc_score, plot_roc_curve

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import roc_auc_score, plot_roc_curve
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import ComplementNB, GaussianNB
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.datasets import make_friedman1
from sklearn.feature_selection import RFE
from sklearn.svm import SVR
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
data = pd.read_csv('../../../../../Downloads/Data/fake_job_postings.csv')

# %%
data.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# 2  Our client, located in Houston, is actively se...
# 3  THE COMPANY: ESRI – Environmental Systems Rese...
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...
#
#                                         requirements  \
# 0  Experience with content management systems a m...
# 1  What we expect from you:Your key responsibilit...
# 2  Implement pre-commissioning and commissioning ...
# 3  EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4  QUALIFICATIONS:RN license in the State of Texa...
#
#                                             benefits  telecommuting  \
# 0                                                NaN              0
# 1  What you will get from usThrough being part of...              0
# 2                                                NaN              0
# 3  Our culture is anything but corporate—we have ...              0
# 4                              Full Benefits Offered              0
#
#    has_company_logo  has_questions employment_type required_experience  \
# 0                 1              0           Other          Internship
# 1                 1              0       Full-time      Not Applicable
# 2                 1              0             NaN                 NaN
# 3                 1              0       Full-time    Mid-Senior level
# 4                 1              1       Full-time    Mid-Senior level
#
#   required_education                   industry              function  \
# 0                NaN                        NaN             Marketing
# 1                NaN  Marketing and Advertising      Customer Service
# 2                NaN                        NaN                   NaN
# 3  Bachelor's Degree          Computer Software                 Sales
# 4  Bachelor's Degree     Hospital & Health Care  Health Care Provider
#
#    fraudulent
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  int64
#  1   title                17880 non-null  object
#  2   location             17534 non-null  object
#  3   department           6333 non-null   object
#  4   salary_range         2868 non-null   object
#  5   company_profile      14572 non-null  object
#  6   description          17879 non-null  object
#  7   requirements         15185 non-null  object
#  8   benefits             10670 non-null  object
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      14409 non-null  object
#  13  required_experience  10830 non-null  object
#  14  required_education   9775 non-null   object
#  15  industry             12977 non-null  object
#  16  function             11425 non-null  object
#  17  fraudulent           17880 non-null  int64
# dtypes: int64(5), object(13)
# memory usage: 2.5+ MB

# %%
data['required_experience'].value_counts()
# Out:
# Mid-Senior level    3809
# Entry level         2697
# Associate           2297
# Not Applicable      1116
# Director             389
# Internship           381
# Executive            141
# Name: required_experience, dtype: int64

# %%
data['location'].value_counts()
# Out:
# GB, LND, London                                    718
# US, NY, New York                                   658
# US, CA, San Francisco                              472
# GR, I, Athens                                      464
# US, ,                                              339
#                                                   ...
# US, , New Orleans                                    1
# US, NC, Clemmons                                     1
# GB, LEC, Leicester                                   1
# GB, EDH,                                             1
# CA, ON, London/Sarnia/Chatham/Windsor/Kitchener      1
# Name: location, Length: 3105, dtype: int64

# %%
data['location'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17875    False
# 17876    False
# 17877    False
# 17878    False
# 17879    False
# Name: location, Length: 17880, dtype: bool

# %%
data['location']
# Out:
# 0            US, NY, New York
# 1              NZ, , Auckland
# 2               US, IA, Wever
# 3          US, DC, Washington
# 4          US, FL, Fort Worth
#                  ...
# 17875         CA, ON, Toronto
# 17876    US, PA, Philadelphia
# 17877         US, TX, Houston
# 17878           NG, LA, Lagos
# 17879       NZ, N, Wellington
# Name: location, Length: 17880, dtype: object

# %%
data['country'] = data['location'].str[:2]
data['country']
# Out:
# 0        US
# 1        NZ
# 2        US
# 3        US
# 4        US
#          ..
# 17875    CA
# 17876    US
# 17877    US
# 17878    NG
# 17879    NZ
# Name: country, Length: 17880, dtype: object

# %%
data.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# 2  Our client, located in Houston, is actively se...
# 3  THE COMPANY: ESRI – Environmental Systems Rese...
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...
#
#                                         requirements  \
# 0  Experience with content management systems a m...
# 1  What we expect from you:Your key responsibilit...
# 2  Implement pre-commissioning and commissioning ...
# 3  EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4  QUALIFICATIONS:RN license in the State of Texa...
#
#                                             benefits  telecommuting  \
# 0                                                NaN              0
# 1  What you will get from usThrough being part of...              0
# 2                                                NaN              0
# 3  Our culture is anything but corporate—we have ...              0
# 4                              Full Benefits Offered              0
#
#    has_company_logo  has_questions employment_type required_experience  \
# 0                 1              0           Other          Internship
# 1                 1              0       Full-time      Not Applicable
# 2                 1              0             NaN                 NaN
# 3                 1              0       Full-time    Mid-Senior level
# 4                 1              1       Full-time    Mid-Senior level
#
#   required_education                   industry              function  \
# 0                NaN                        NaN             Marketing
# 1                NaN  Marketing and Advertising      Customer Service
# 2                NaN                        NaN                   NaN
# 3  Bachelor's Degree          Computer Software                 Sales
# 4  Bachelor's Degree     Hospital & Health Care  Health Care Provider
#
#    fraudulent country
# 0           0      US
# 1           0      NZ
# 2           0      US
# 3           0      US
# 4           0      US

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  int64
#  1   title                17880 non-null  object
#  2   location             17534 non-null  object
#  3   department           6333 non-null   object
#  4   salary_range         2868 non-null   object
#  5   company_profile      14572 non-null  object
#  6   description          17879 non-null  object
#  7   requirements         15185 non-null  object
#  8   benefits             10670 non-null  object
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      14409 non-null  object
#  13  required_experience  10830 non-null  object
#  14  required_education   9775 non-null   object
#  15  industry             12977 non-null  object
#  16  function             11425 non-null  object
#  17  fraudulent           17880 non-null  int64
#  18  country              17534 non-null  object
# dtypes: int64(5), object(14)
# memory usage: 2.6+ MB

# %%
data['employment_type'].value_counts()
# Out:
# Full-time    11620
# Contract      1524
# Part-time      797
# Temporary      241
# Other          227
# Name: employment_type, dtype: int64

# %%
data.loc[data['country'].isnull() == True]
# Out:
#        job_id                                              title location  \
# 144       145                                       Forward Cap.      NaN
# 204       205                            Junior Python Developer      NaN
# 234       235  Postgraduate Certificate in Social Innovation ...      NaN
# 325       326                          Head of Quality Assurance      NaN
# 349       350  Embedded Systems / Telematics Security Consultant      NaN
# ...       ...                                                ...      ...
# 17792   17793                             Rooms Division Manager      NaN
# 17809   17810  Data Entry / Administrative Assitstant / Admin...      NaN
# 17821   17822                                       Webcam Model      NaN
# 17822   17823                                             5 Guys      NaN
# 17837   17838                          Senior Backend Developers      NaN
#
#                   department salary_range  \
# 144                      NaN          NaN
# 204                  Line-Up          NaN
# 234                      NaN          NaN
# 325                      NaN          NaN
# 349    Professional Services          NaN
# ...                      ...          ...
# 17792                    NaN          NaN
# 17809                    NaN          NaN
# 17821                    NaN          NaN
# 17822                    NaN          NaN
# 17837                    NaN          NaN
#
#                                          company_profile  \
# 144                                                  NaN
# 204    Playfair Capital is an early stage technology ...
# 234    The Amani Institute is about developing whole ...
# 325    Gelato Group is a SaaS company. We've develope...
# 349    Cylance is a global cybersecurity products and...
# ...                                                  ...
# 17792  Awarded by Expatriate Lifestyle Magazine with ...
# 17809                                                NaN
# 17821                                                NaN
# 17822                                                NaN
# 17837  Gelato Group is a SaaS company. We've develope...
#
#                                              description  \
# 144    The group has raised a fund for the purchase o...
# 204    Who we’re looking forMaker MentalityAre you fo...
# 234    This unique, field-based, full-time program br...
# 325    Following our global expansion we are seeking ...
# 349    SummaryImmediate requirement for an advanced t...
# ...                                                  ...
# 17792  The Rooms Division Manager is responsible for ...
# 17809  As a  Data Entry / Administrative Assitstant /...
# 17821  Internet Modeling is a premier adult modeling ...
# 17822  Analyze the excel books of the franchise and t...
# 17837  Following our global expansion we are seeking ...
#
#                                             requirements  \
# 144                                                  NaN
# 204    Skills and experienceDegree in Computer Scienc...
# 234    What do we look for in a program participant?I...
# 325    A minimum of B.S. degree in Information Techno...
# 349    QualificationsBachelor degree in Information T...
# ...                                                  ...
# 17792  High school or equivalent education required. ...
# 17809                                                NaN
# 17821  In order to be considered for a webcam model p...
# 17822                                                NaN
# 17837  A minimum of B.S. degree in Information Techno...
#
#                                                 benefits  telecommuting  \
# 144                                                  NaN              0
# 204                                                  NaN              0
# 234    Sign up for:25 classmates from around the worl...              0
# 325                                                  NaN              0
# 349                                                  NaN              0
# ...                                                  ...            ...
# 17792                                                NaN              0
# 17809                                                NaN              1
# 17821  We provide the following benefits to all our w...              0
# 17822                                                NaN              0
# 17837                                                NaN              0
#
#        has_company_logo  has_questions employment_type required_experience  \
# 144                   0              0           Other                 NaN
# 204                   1              0           Other                 NaN
# 234                   1              1           Other                 NaN
# 325                   1              0           Other                 NaN
# 349                   1              0           Other                 NaN
# ...                 ...            ...             ...                 ...
# 17792                 1              0           Other                 NaN
# 17809                 0              0       Full-time         Entry level
# 17821                 0              1           Other                 NaN
# 17822                 0              0           Other                 NaN
# 17837                 1              0           Other                 NaN
#
#       required_education            industry        function  fraudulent  \
# 144                  NaN                 NaN           Other           1
# 204                  NaN                 NaN           Other           0
# 234                  NaN                 NaN           Other           0
# 325                  NaN                 NaN           Other           0
# 349                  NaN                 NaN           Other           0
# ...                  ...                 ...             ...         ...
# 17792                NaN                 NaN           Other           1
# 17809        Unspecified  Telecommunications  Administrative           1
# 17821                NaN                 NaN           Other           1
# 17822                NaN                 NaN           Other           1
# 17837                NaN                 NaN           Other           0
#
#       country
# 144       NaN
# 204       NaN
# 234       NaN
# 325       NaN
# 349       NaN
# ...       ...
# 17792     NaN
# 17809     NaN
# 17821     NaN
# 17822     NaN
# 17837     NaN
#
# [346 rows x 19 columns]

# %%
data['country'].isna().sum()
# Out:
# 0

# %%
data['employment_type'] = data['employment_type'].fillna('Other')

# %%
data['function'] = data['function'].fillna('Other')

# %%
data['country'].value_counts().index
# Out:
# Index(['US', 'GB', 'GR', 'CA', 'DE', 'NZ', 'IN', 'AU', 'PH', 'NL', 'BE', 'IE',
#        'SG', 'HK', 'PL', 'EE', 'IL', 'FR', 'ES', 'AE', 'EG', 'SE', 'RO', 'DK',
#        'ZA', 'BR', 'IT', 'FI', 'PK', 'LT', 'MY', 'QA', 'RU', 'JP', 'PT', 'MX',
#        'TR', 'BG', 'CN', 'SA', 'CH', 'AT', 'MU', 'HU', 'UA', 'ID', 'MT', 'CY',
#        'TH', 'NG', 'KR', 'IQ', 'LU', 'PA', 'AR', 'BH', 'BY', 'NO', 'RS', 'KE',
#        'CZ', 'LV', 'VN', 'TW', 'TT', 'NI', 'VI', 'ZM', 'SK', 'LK', 'CL', 'KW',
#        'TN', 'BD', 'AM', 'IS', 'MA', 'SV', 'UG', 'GH', 'AL', 'PE', 'HR', 'JM',
#        'KZ', 'SI', 'KH', 'SD', 'CM', 'CO'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  int64
#  1   title                17880 non-null  object
#  2   location             17534 non-null  object
#  3   department           6333 non-null   object
#  4   salary_range         2868 non-null   object
#  5   company_profile      14572 non-null  object
#  6   description          17879 non-null  object
#  7   requirements         15185 non-null  object
#  8   benefits             10670 non-null  object
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      17880 non-null  object
#  13  required_experience  10830 non-null  object
#  14  required_education   9775 non-null   object
#  15  industry             12977 non-null  object
#  16  function             17880 non-null  object
#  17  fraudulent           17880 non-null  int64
#  18  country              17534 non-null  object
# dtypes: int64(5), object(14)
# memory usage: 2.6+ MB

# %%
data = data.dropna(subset= ['country'])

# %%
data['country'].isna().sum()
# Out:
# 346

# %%
data['function'].value_counts()
# Out:
# Information Technology    1749
# Sales                     1468
# Engineering               1348
# Customer Service          1229
# Marketing                  830
# Administrative             630
# Design                     340
# Health Care Provider       338
# Education                  325
# Other                      325
# Management                 317
# Business Development       228
# Accounting/Auditing        212
# Human Resources            205
# Project Management         183
# Finance                    172
# Consulting                 144
# Writing/Editing            132
# Art/Creative               132
# Production                 116
# Product Management         114
# Quality Assurance          111
# Advertising                 90
# Business Analyst            84
# Data Analyst                82
# Public Relations            76
# Manufacturing               74
# General Business            68
# Research                    50
# Legal                       47
# Strategy/Planning           46
# Training                    38
# Supply Chain                36
# Financial Analyst           33
# Distribution                24
# Purchasing                  15
# Science                     14
# Name: function, dtype: int64

# %%
data[['country', 'has_company_logo', 'employment_type','function' ]].isna().sum()
# Out:
# country             0
# has_company_logo    0
# employment_type     0
# function            0
# dtype: int64

# %%
# Setting our X and y variables
X = data[['country', 'has_company_logo', 'employment_type','function' ]]
y = data['fraudulent']
# Preparing our hold out data for train test split
X_cols = X.columns
X, X_hold, y, y_hold = train_test_split(X, y, random_state=42, test_size=.05)
# Regular train test split
X_train, X_test, y_train, y_test= train_test_split(X, y, random_state=42)

# %%
# Showings the probablities of fraudlent status
y_train.value_counts(normalize=True)
# Out:
# 0    0.951809
# 1    0.048191
# Name: fraudulent, dtype: float64

# %%
# Making predicts using baseline model
preds = [0] * len(y_train)
preds_test = [0] * len(y_test)
# Showing us the accuracy score for modelless baseline
print(f' Accuracy score of train data {accuracy_score(y_train, preds)}')
print('*' *48)
print(f' Accuracy score of test data {accuracy_score(y_test, preds_test)}')
# Out:
#  Accuracy score of train data 0.951809157861031
# ************************************************
#  Accuracy score of test data 0.9522208883553421

# %%
 data[['country', 'has_company_logo', 'employment_type','function' ]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17534 entries, 0 to 17879
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           17534 non-null  object
#  1   has_company_logo  17534 non-null  int64
#  2   employment_type   17534 non-null  object
#  3   function          17534 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 684.9+ KB

# %%
# Grouping categorical columns
cat_columns = [c for c in X_train.columns if X_train[c].dtype == 'O']
# Grouping numerical columns
num_columns = [c for c in X_train.columns if X_train[c].dtype in ['int64']]
# Combining the numerical and categorical columns 
used_cols = [*cat_columns, *num_columns]

# Instantiating OneHotEncoder(ohe)
cat_transformer = OneHotEncoder(drop='first')
# Instantiating StandardScaler
num_transformer = StandardScaler()

# Instantiating ColumnTransformer
preprocessor = ColumnTransformer([
    ('cats', cat_transformer, cat_columns),
    ('nums', num_transformer, num_columns)
])

# %%
# Function to show train and test accuracy scores
def evaluate(model, Xtr, Xte, ytr, yte):
    train_preds = model.predict(Xtr)
    test_preds = model.predict(Xte)

    train_probas = model.predict_proba(Xtr)[:,1]
    test_probas = model.predict_proba(Xte)[:,1]
    
    plot_confusion_matrix(model, Xte, yte)
    
    plot_roc_curve(model, Xte, yte)
    
    print(f"Train Accuracy: {accuracy_score(y_train, train_preds):.4f}")
    print("*" * 20)
    print(f"Test Accuracy: {accuracy_score(y_test, test_preds):.4f}")

# %%
# Using pipline to instantiate Logistic Regression 
lr = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('logreg', LogisticRegression())
])

# Fitting model onto train data
lr.fit(X_train[used_cols], y_train)

# Getting score, confusion matrix, and graph
evaluate(lr, X_train[used_cols], X_test[used_cols], y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-6b79af6fd8ba> in <module>
#       9
#      10 # Getting score, confusion matrix, and graph
# ---> 11 evaluate(lr, X_train[used_cols], X_test[used_cols], y_train, y_test)
#
# <ipython-input-133-8b7f64d60938> in evaluate(model, Xtr, Xte, ytr, yte)
#       2 def evaluate(model, Xtr, Xte, ytr, yte):
#       3     train_preds = model.predict(Xtr)
# ----> 4     test_preds = model.predict(Xte)
#       5
#       6     train_probas = model.predict_proba(Xtr)[:,1]
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     117
#     118         # lambda, but not partial, allows help() to work with update_wrapper
# --> 119         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     120         # update the docstring of the returned function
#     121         update_wrapper(out, self.fn)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/pipeline.py in predict(self, X, **predict_params)
#     405         Xt = X
#     406         for _, name, transform in self._iter(with_final=False):
# --> 407             Xt = transform.transform(Xt)
#     408         return self.steps[-1][-1].predict(Xt, **predict_params)
#     409
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/compose/_column_transformer.py in transform(self, X)
#     602         # TODO: also call _check_n_features(reset=False) in 0.24
#     603         self._validate_features(X.shape[1], X_feature_names)
# --> 604         Xs = self._fit_transform(X, None, _transform_one, fitted=True)
#     605         self._validate_output(Xs)
#     606
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/compose/_column_transformer.py in _fit_transform(self, X, y, func, fitted)
#     456             self._iter(fitted=fitted, replace_strings=True))
#     457         try:
# --> 458             return Parallel(n_jobs=self.n_jobs)(
#     459                 delayed(func)(
#     460                     transformer=clone(trans) if not fitted else trans,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/pipeline.py in _transform_one(transformer, X, y, weight, **fit_params)
#     717
#     718 def _transform_one(transformer, X, y, weight, **fit_params):
# --> 719     res = transformer.transform(X)
#     720     # if we have a weight for this transformer, multiply output
#     721     if weight is None:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/preprocessing/_encoders.py in transform(self, X)
#     426         check_is_fitted(self)
#     427         # validation of X happens in _check_X called by _transform
# --> 428         X_int, X_mask = self._transform(X, handle_unknown=self.handle_unknown)
#     429
#     430         n_samples, n_features = X_int.shape
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/preprocessing/_encoders.py in _transform(self, X, handle_unknown)
#     122                     msg = ("Found unknown categories {0} in column {1}"
#     123                            " during transform".format(diff, i))
# --> 124                     raise ValueError(msg)
#     125                 else:
#     126                     # Set the problematic rows to an acceptable value and
#
# ValueError: Found unknown categories ['JM', 'KZ'] in column 0 during transform

# %%
X_train[used_cols]['country'].value_counts().index
# Out:
# Index(['US', 'GB', 'GR', 'CA', 'DE', 'NZ', 'IN', 'AU', 'NL', 'PH', 'BE', 'IE',
#        'PL', 'FR', 'HK', 'SG', 'IL', 'EE', 'ES', 'AE', 'EG', 'SE', 'RO', 'ZA',
#        'DK', 'IT', 'BR', 'PK', 'FI', 'RU', 'MX', 'QA', 'JP', 'MY', 'PT', 'CN',
#        'LT', 'TR', 'UA', 'BG', 'HU', 'SA', 'IQ', 'MT', 'ID', 'MU', 'CH', 'KR',
#        'LU', 'CY', 'AT', 'AR', 'PA', 'NG', 'BY', 'TH', 'NO', 'RS', 'LV', 'NI',
#        'KE', 'CZ', 'BH', 'VN', 'BD', 'TT', 'CL', 'KW', 'VI', 'TW', 'AL', 'CM',
#        'LK', 'SI', 'HR', 'PE', 'ZM', 'GH', 'TN', 'UG', 'SV', 'SK', 'AM', 'SD',
#        'IS', 'KH', 'CO'],
#       dtype='object')

# %%
# Using pipline to instantiate Decision Tree
dt = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('tree', DecisionTreeClassifier(random_state=42, max_depth=10))
])
# Fitting model onto training data
dt.fit(X_train[used_cols], y_train)

# Making predictions on train and test data
train_preds = dt.predict(X_train[used_cols])
test_preds = dt.predict(X_test[used_cols])

# Calulating predict proba for both train and test
train_probas = dt.predict_proba(X_train[used_cols])[:,1]
test_probas = dt.predict_proba(X_test[used_cols])[:,1]

# Getting score, confusion matrix, and graph
evaluate(dt, X_train[used_cols], X_test[used_cols], y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-cf5bc9529378> in <module>
#       9 # Making predictions on train and test data
#      10 train_preds = dt.predict(X_train[used_cols])
# ---> 11 test_preds = dt.predict(X_test[used_cols])
#      12
#      13 # Calulating predict proba for both train and test
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     117
#     118         # lambda, but not partial, allows help() to work with update_wrapper
# --> 119         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     120         # update the docstring of the returned function
#     121         update_wrapper(out, self.fn)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/pipeline.py in predict(self, X, **predict_params)
#     405         Xt = X
#     406         for _, name, transform in self._iter(with_final=False):
# --> 407             Xt = transform.transform(Xt)
#     408         return self.steps[-1][-1].predict(Xt, **predict_params)
#     409
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/compose/_column_transformer.py in transform(self, X)
#     602         # TODO: also call _check_n_features(reset=False) in 0.24
#     603         self._validate_features(X.shape[1], X_feature_names)
# --> 604         Xs = self._fit_transform(X, None, _transform_one, fitted=True)
#     605         self._validate_output(Xs)
#     606
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/compose/_column_transformer.py in _fit_transform(self, X, y, func, fitted)
#     456             self._iter(fitted=fitted, replace_strings=True))
#     457         try:
# --> 458             return Parallel(n_jobs=self.n_jobs)(
#     459                 delayed(func)(
#     460                     transformer=clone(trans) if not fitted else trans,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/pipeline.py in _transform_one(transformer, X, y, weight, **fit_params)
#     717
#     718 def _transform_one(transformer, X, y, weight, **fit_params):
# --> 719     res = transformer.transform(X)
#     720     # if we have a weight for this transformer, multiply output
#     721     if weight is None:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/preprocessing/_encoders.py in transform(self, X)
#     426         check_is_fitted(self)
#     427         # validation of X happens in _check_X called by _transform
# --> 428         X_int, X_mask = self._transform(X, handle_unknown=self.handle_unknown)
#     429
#     430         n_samples, n_features = X_int.shape
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/preprocessing/_encoders.py in _transform(self, X, handle_unknown)
#     122                     msg = ("Found unknown categories {0} in column {1}"
#     123                            " during transform".format(diff, i))
# --> 124                     raise ValueError(msg)
#     125                 else:
#     126                     # Set the problematic rows to an acceptable value and
#
# ValueError: Found unknown categories ['JM', 'KZ'] in column 0 during transform
